# %% [markdown]
# # EDA -2

# %%
#step 1

# import 4 required package for EDA

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
file_path ="C:\\Users\\hp\\OneDrive\\Documents\\Fullstack DataScience Materials\\Data\\Districtwise_SchoolData.csv"
school_data=pd.read_csv(file_path)
school_data
# Out:
#       Unnamed: 0                                         Unnamed: 1  \
# 0            NaN                                                NaN
# 1     State Code                                         State Name
# 2        Statecd                                        State Name
# 3             35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4             35  ANDAMAN & NICOBAR ISLANDS                     ...
# ...          ...                                                ...
# 1322          19  WEST BENGAL                                   ...
# 1323          19  WEST BENGAL                                   ...
# 1324          19  WEST BENGAL                                   ...
# 1325          19  WEST BENGAL                                   ...
# 1326          19  WEST BENGAL                                   ...
#
#          Unnamed: 2                                         Unnamed: 3  \
# 0               NaN                                                NaN
# ...

# %% [markdown]
# # shape

# %%
# it will give you number of row and column
# eg:-
school_data.shape
# Out:
# (1327, 245)

# %%
#check the tpye of data
type(school_data)
# Out:
# pandas.core.frame.DataFrame

# %%
#check the tpye of data
#check the tpye of data
school_data.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 #check the tpye of data
#       2 #check the tpye of data
# ----> 3 school_data.shape()
#
# TypeError: 'tuple' object is not callable

# %%
# TypeError: 'tuple' object is not callable 

# this mean it is not a function

# %%
school_data.shape[0]*school_data.shape[1]
# Out:
# 325115

# %%
school_data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 235', 'Unnamed: 236', 'Unnamed: 237', 'Unnamed: 238',
#        'Unnamed: 239', 'Unnamed: 240', 'Unnamed: 241', 'Unnamed: 242',
#        'Unnamed: 243', 'Unnamed: 244'],
#       dtype='object', length=245)

# %%
type(school_data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
school_data.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 235', 'Unnamed: 236', 'Unnamed: 237', 'Unnamed: 238',
#        'Unnamed: 239', 'Unnamed: 240', 'Unnamed: 241', 'Unnamed: 242',
#        'Unnamed: 243', 'Unnamed: 244'],
#       dtype='object', length=245)>

# %%
school_data.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Unnamed: 43',
#  'Unnamed: 44',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Unnamed: 48',
#  'Unnamed: 49',
#  'Unnamed: 50',
#  'Unnamed: 51',
#  'Unnamed: 52',
#  'Unnamed: 53',
#  'Unnamed: 54',
#  'Unnamed: 55',
# ...

# %%
dict()===to_dict
list()===to_dict

# %%
school_data.dtypes
# Out:
# Unnamed: 0      object
# Unnamed: 1      object
# Unnamed: 2      object
# Unnamed: 3      object
# Unnamed: 4      object
#                  ...
# Unnamed: 240    object
# Unnamed: 241    object
# Unnamed: 242    object
# Unnamed: 243    object
# Unnamed: 244    object
# Length: 245, dtype: object

# %%
school_data.dtypes.index
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        ...
#        'Unnamed: 235', 'Unnamed: 236', 'Unnamed: 237', 'Unnamed: 238',
#        'Unnamed: 239', 'Unnamed: 240', 'Unnamed: 241', 'Unnamed: 242',
#        'Unnamed: 243', 'Unnamed: 244'],
#       dtype='object', length=245)

# %%
school_data.dtypes.keys
# Out:
# <bound method Series.keys of Unnamed: 0      object
# Unnamed: 1      object
# Unnamed: 2      object
# Unnamed: 3      object
# Unnamed: 4      object
#                  ...
# Unnamed: 240    object
# Unnamed: 241    object
# Unnamed: 242    object
# Unnamed: 243    object
# Unnamed: 244    object
# Length: 245, dtype: object>

# %%
school_data.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
# ...

# %%
# numpy n dimensions array

# %%
import numpy as np
np.array([1,2,3])+np.array([4,5,6])
# Out:
# array([5, 7, 9])

# %%
# Note

array[] = numpy
index[] = pandas index

pandas.dataframe
pandas.series

# %%
# create two list

# categorical list
# numerical list

# %%
dict(school_data.dtypes)
# Out:
# {'Unnamed: 0': dtype('O'),
#  'Unnamed: 1': dtype('O'),
#  'Unnamed: 2': dtype('O'),
#  'Unnamed: 3': dtype('O'),
#  'Unnamed: 4': dtype('O'),
#  'Unnamed: 5': dtype('O'),
#  'Unnamed: 6': dtype('O'),
#  'Unnamed: 7': dtype('O'),
#  'Unnamed: 8': dtype('O'),
#  'Unnamed: 9': dtype('O'),
#  'Unnamed: 10': dtype('O'),
#  'Unnamed: 11': dtype('O'),
#  'Unnamed: 12': dtype('O'),
#  'Unnamed: 13': dtype('O'),
#  'Unnamed: 14': dtype('O'),
#  'Unnamed: 15': dtype('O'),
#  'Unnamed: 16': dtype('O'),
#  'Unnamed: 17': dtype('O'),
#  'Unnamed: 18': dtype('O'),
#  'Unnamed: 19': dtype('O'),
#  'Unnamed: 20': dtype('O'),
#  'Unnamed: 21': dtype('O'),
#  'Unnamed: 22': dtype('O'),
#  'Unnamed: 23': dtype('O'),
#  'Unnamed: 24': dtype('O'),
#  'Unnamed: 25': dtype('O'),
#  'Unnamed: 26': dtype('O'),
#  'Unnamed: 27': dtype('O'),
#  'Unnamed: 28': dtype('O'),
#  'Unnamed: 29': dtype('O'),
#  'Unnamed: 30': dtype('O'),
#  'Unnamed: 31': dtype('O'),
#  'Unnamed: 32': dtype('O'),
# ...

# %%
for i,j in dict(school_data.dtypes).items():
    print(j)
# Out:
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# ...

# %%
list1=[100,200,300]
school_data.take(list1)
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 100         10  BIHAR                                         ...       1032
# 200          2  HIMACHAL PRADESH                              ...        201
# 300         32  KERALA                                        ...       3206
#
#                                             Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 100  ROHTAS                                        ...    2012-13       1283
# 200  CHAMBA                                        ...    2012-13       1134
# 300  PALAKKAD                                      ...    2012-13        227
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 235  \
# 100        773          3         11          1  ...           11
# 200          0          5        250         90  ...          167
# 300         45         21          3         38  ...           25
#
#     Unnamed: 236 Unnamed: 237 Unnamed: 238 Unnamed: 239 Unnamed: 240  \
# ...

# %%
# to see particular  cell data
# to see sample of data

# %%
school_data.take([100,150,200],axis=0)
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 100         10  BIHAR                                         ...       1032
# 150         30  GOA                                           ...       3001
# 200          2  HIMACHAL PRADESH                              ...        201
#
#                                             Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 100  ROHTAS                                        ...    2012-13       1283
# 150  NORTH GOA                                     ...    2012-13        522
# 200  CHAMBA                                        ...    2012-13       1134
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 235  \
# 100        773          3         11          1  ...           11
# 150         31          3          4          3  ...           12
# 200          0          5        250         90  ...          167
#
#     Unnamed: 236 Unnamed: 237 Unnamed: 238 Unnamed: 239 Unnamed: 240  \
# ...

# %%
# to print only targeted columns
school_data.take([3,4,7],axis=1)
# Out:
#                                              Unnamed: 3     Unnamed: 4  \
# 0                                                   NaN            NaN
# 1                                         District Name  Academic Year
# 2                                              distname        ac_year
# 3     ANDAMANS                                      ...        2012-13
# 4     MIDDLE AND NORTH ANDAMANS                     ...        2012-13
# ...                                                 ...            ...
# 1322  PURBA MEDINIPUR                               ...        2013-14
# 1323  PURULIYA                                      ...        2013-14
# 1324  SILIGURI                                      ...        2013-14
# 1325  SOUTH  TWENTY FOUR PARGAN                     ...        2013-14
# 1326  UTTAR DINAJPUR                                ...        2013-14
#
#                                           Unnamed: 7
# 0                                                NaN
# ...

# %%
school_data.take([130,140,170]).take([4,5,7],axis=1)
# Out:
#     Unnamed: 4 Unnamed: 5 Unnamed: 7
# 130    2012-13        734          0
# 140    2012-13         19          0
# 170    2012-13         59          2

# %% [markdown]
# # iloc - loc

# %%
# school_data.iloc[<rows>,<column>]
# school_data.iloc[<start:end>,<start:end>]

school_data.iloc[50:55,2:5]
# Out:
#    Unnamed: 2                                         Unnamed: 3 Unnamed: 4
# 50       1808  DARRANG                                       ...    2012-13
# 51       1813  DHEMAJI                                       ...    2012-13
# 52       1802  DHUBRI                                        ...    2012-13
# 53       1815  DIBRUGARH                                     ...    2012-13
# 54       1820  DIMA HASAO                                    ...    2012-13

# %%
# use of loc

# list rows
# list of column
school_data.loc[[100,129]]
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 100         10  BIHAR                                         ...       1032
# 129         22  CHHATTISGARH                                  ...       2212
#
#                                             Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 100  ROHTAS                                        ...    2012-13       1283
# 129  MAHASAMUND                                    ...    2012-13       1341
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 235  \
# 100        773          3         11          1  ...           11
# 129          1          0        497          9  ...          530
#
#     Unnamed: 236 Unnamed: 237 Unnamed: 238 Unnamed: 239 Unnamed: 240  \
# 100            1           41            7         1490          707
# 129           29            1            1          436          261
#
#     Unnamed: 241 Unnamed: 242 Unnamed: 243 Unnamed: 244
# ...

# %% [markdown]
# # null

# %%
#  to find missing value
# give true or false

# %%
school_data.isnull()
# Out:
#       Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0           True        True        True        True        True       False
# 1          False       False       False       False       False       False
# 2          False       False       False       False       False       False
# 3          False       False       False       False       False       False
# 4          False       False       False       False       False       False
# ...          ...         ...         ...         ...         ...         ...
# 1322       False       False       False       False       False       False
# 1323       False       False       False       False       False       False
# 1324       False       False       False       False       False       False
# 1325       False       False       False       False       False       False
# 1326       False       False       False       False       False       False
#
# ...

# %%
school_data.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0                                         Unnamed: 1  \
# 0            NaN                                                NaN
# 1     State Code                                         State Name
# 2        Statecd                                        State Name
# 3             35  ANDAMAN & NICOBAR ISLANDS                     ...
# 4             35  ANDAMAN & NICOBAR ISLANDS                     ...
# ...          ...                                                ...
# 1322          19  WEST BENGAL                                   ...
# 1323          19  WEST BENGAL                                   ...
# 1324          19  WEST BENGAL                                   ...
# 1325          19  WEST BENGAL                                   ...
# 1326          19  WEST BENGAL                                   ...
#
#          Unnamed: 2                                         Unnamed: 3  \
# ...
