# %% [markdown]
# $$$$$$$$$----EDA---------$$$$$$$$$

# %% [raw]
# packages:-
#
#
# eda:- [we will use only 4]
# 1. pandas : data frame analysis
# 2. numpy : numerical python/ number python
# 3. matplotlib : mta plot library , it is for library
# 4. seaborn: plot
# 5. plotly : plot
# 6. bokhe : plot
#
#
# *****************
#
#     ml package:-
#
# 7. scikit-learn : sk learn
#     ml related
#
# ************************
#
#     dl [deep learning] packages:
#
#     [tensorflows and keras works together]
#
# 8. tensorflow [develop by google]
#
# 9. keras
#
# 10. pytorch
#
# 11. cv : (computer vision)
#
# ******************************
# NLP
#
# 12. NLTK
# 13. Scipy
#
# ******************Generative AI ***************
#
# 14. Chat gpt : openAI
# 15. makerSuit: google generative AI
# 16.Amazon Q
#
# ****************Hugging face transformer (BERT model )---------
#
# 17. Transformer
#
#
# *******************other****************
#
# random
# math
# os
# sys
# time
#
# ************************Azure ML *********************
#
# azure package
# GCP vertex AI
# AWS sage maker

# %% [markdown]
# $ step -  1$
# - import required package
# - import pandas as pd
# - import numpy as np
# - import patplolib.pyplot as plt
# - import seaborn as sns

# %% [markdown]
# $ step -2 $
# - read the data
# - visa data sets
#   - file location
#   - file name
#   - file extension

# %%
import pandas as pd
file_path ="C:\\Users\\hp\\OneDrive\\Documents\\Fullstack DataScience Materials\\Data\\Invistico_Airline.csv"
pd.read_csv(file_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 file_path ="C:\\Users\\hp\\OneDrive\\Documents\\Fullstack DataScience Materials\\Data\\Invistico_Airline.csv"
# ----> 3 pd.read_csv(file_path)
#
# ...

# %%
import required package
import pandas as pd
import numpy as np
import matplolib.pyplot as plt
import seaborn as sns
# Out:
#   Cell In[3], line 1
#     import required package
#                     ^
# SyntaxError: invalid syntax

# %%
file_path ="C:\\Users\\hp\\OneDrive\\Documents\\Fullstack DataScience Materials\\Data\\Invistico_Airline.csv"
file=open(file_path,encoding="utf-8-sig")
print(file.read())
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
import pandas as pd
file_path ="C:\\Users\\hp\\OneDrive\\Documents\\Fullstack DataScience Materials\\Data\\Loan_Details_transactions.csv"
file=open(file_path,encoding="utf-8-sig")

pd.read_csv(file_path)
# Out:
#        Loan_Id  Disbursed_Amount  Asset_Cost    ltv  Branch_Id City_Code  \
# 0            1             36439       65850  56.19         64      CT01
# 1            2             48749       69303  72.15         67      CT03
# 2            3             55348       66340  85.00          2      CT13
# 3            4             48849       64133  77.96        217      CT06
# 4            5             40394       59386  70.72         74      CT03
# ...        ...               ...         ...    ...        ...       ...
# 23310    23311            123661      185371  69.59         34      CT03
# 23311    23312             78879      122878  65.11          5      CT15
# 23312    23313             49349       67695  73.86         48      CT22
# 23313    23314             70897       84400  86.00          2      CT03
# 23314    23315             58206       71372  85.00         34      CT09
#
#       State_Code  Postal_Code Date_of_Birth Employment_Type  ...  \
# ...

# %%
# step - 3 
#- create a dataframe using lists
import pandas as pd
list1 = ["ram","raheem","robert"]
list2= [30,40,50]

pd.DataFrame(zip(list1,list2))
# Out:
#         0   1
# 0     ram  30
# 1  raheem  40
# 2  robert  50

# %%
import pandas as pd
list1 = ["ram","raheem","robert"]
list2= [30,40,50]

names=pd.DataFrame(zip(list1,list2),columns=["name","age"])
# Out:
#      name  age
# 0     ram   30
# 1  raheem   40
# 2  robert   50

# %%
import pandas as pd
list1 = ["ram","raheem","robert"]
list2= [30,40,50]
cols=["name","age"]
names=pd.DataFrame(zip(list1,list2),columns=cols)

# %% [markdown]
# $ step - 4 $
#
# - how to save the data frame in local

# %%
# what is your data frame name : names
# where you want to save
# what name you want to provide
names.to_csv("C:\\Users\\hp\\OneDrive\\Documents\\Fullstack DataScience Materials\\Data\\NAMES.csv")

# %%
import pandas as pd

names.to_csv("NAMES1.csv",index=False)

# it will not create extra column as index
# shift + tab give you hint for extra information

# %%
names["city"]=["hyd","che","blr"]
print(names)
names
# Out:
#      name  age city
# 0     ram   30  hyd
# 1  raheem   40  che
# 2  robert   50  blr
#      name  age city
# 0     ram   30  hyd
# 1  raheem   40  che
# 2  robert   50  blr

# %%
names["id"]=[1,2,3,4]

#length will not match hence it will give length error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 names["id"]=[1,2,3,4]
#       3 #length will not match hence it will give length error
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
# ...

# %% [raw]
# axis= 1 ====== columns
# axis=0 ===========rows
#
# inplace=True
# # mean data will be overwrite

# %%
names.drop("city",
           axis=1,
           inplace=True)
print(names)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 names.drop("city",
#       2            axis=1,
#       3            inplace=True)
#       4 print(names)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
# ...

# %% [markdown]
# # creating dictionary

# %%
import pandas as pd
dict1={"names":["ram","raheem","robert"],"age":[30,31,32]}
print(dict1)
# Out:
# {'names': ['ram', 'raheem', 'robert'], 'age': [30, 31, 32]}

# %%
pd.DataFrame(dict1)
# Out:
#     names  age
# 0     ram   30
# 1  raheem   31
# 2  robert   32

# %%
# key ---- become = columns
# values ------become = rows

# %%
pd.DataFrame(dict1,index=["a","b","c"])
# Out:
#     names  age
# a     ram   30
# b  raheem   31
# c  robert   32

# %%
# you need able to create a dataframe
