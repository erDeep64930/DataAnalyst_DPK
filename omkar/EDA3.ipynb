# %% [markdown]
# # EDA session 3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np
file_path="C:\\Users\\hp\OneDrive\\Documents\\Fullstack DataScience Materials\\Data\\winequality-white.csv"
wine_data=pd.read_csv(file_path)
wine_data.head()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\O'
# <>:3: SyntaxWarning: invalid escape sequence '\O'
# C:\Users\hp\AppData\Local\Temp\ipykernel_9372\2756002972.py:3: SyntaxWarning: invalid escape sequence '\O'
#   file_path="C:\\Users\\hp\OneDrive\\Documents\\Fullstack DataScience Materials\\Data\\winequality-white.csv"
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7;0.27;0.36;20.7;0.045;45;170;1.001;3;0.45;8.8;6
# 1  6.3;0.3;0.34;1.6;0.049;14;132;0.994;3.3;0.49;9...
# 2  8.1;0.28;0.4;6.9;0.05;30;97;0.9951;3.26;0.44;1...
# 3  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...
# 4  7.2;0.23;0.32;8.5;0.058;47;186;0.9956;3.19;0.4...

# %%
# how to read a column
wine_data.columns
# Out:
# Index(['fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"'], dtype='object')

# %%
#cols=["density"]
#wine_data[cols]

# %% [raw]
# wine_data["xyz"]
# wine_data[["xyz"]]
# wine_data.xyz

# %%
import pandas as pd
import numpy as np
file_path="C:\\Users\\hp\OneDrive\\Documents\\Fullstack DataScience Materials\\Data\\mushrooms.csv"
mush=pd.read_csv(file_path)
mush
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\O'
# <>:3: SyntaxWarning: invalid escape sequence '\O'
# C:\Users\hp\AppData\Local\Temp\ipykernel_9372\103375026.py:3: SyntaxWarning: invalid escape sequence '\O'
#   file_path="C:\\Users\\hp\OneDrive\\Documents\\Fullstack DataScience Materials\\Data\\mushrooms.csv"
#      type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0       p         x           s         n       t    p               f
# 1       e         x           s         y       t    a               f
# 2       e         b           s         w       t    l               f
# 3       p         x           y         w       t    p               f
# 4       e         x           s         g       f    n               f
# ...   ...       ...         ...       ...     ...  ...             ...
# 8119    e         k           s         n       f    n               a
# 8120    e         x           s         n       f    n               a
# ...

# %%
# find the unique 
# read the column
mush["cap_surface"].unique()
#dont apply for unique operation for dataframe :[[]]
#apply only for series
# Out:
# array(['s', 'y', 'f', 'g'], dtype=object)

# %%
len(mush["cap_surface"].unique())
# Out:
# 4

# %%
# how many s as there
#how many y are ther
mush["cap_surface"]=="s"
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 8119     True
# 8120     True
# 8121     True
# 8122    False
# 8123     True
# Name: cap_surface, Length: 8124, dtype: bool

# %%
# read the data
mush[mush["cap_surface"]=="s"]
# Out:
#      type cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0       p         x           s         n       t    p               f
# 1       e         x           s         y       t    a               f
# 2       e         b           s         w       t    l               f
# 4       e         x           s         g       f    n               f
# 6       e         b           s         w       t    a               f
# ...   ...       ...         ...       ...     ...  ...             ...
# 8117    p         k           s         e       f    y               f
# 8119    e         k           s         n       f    n               a
# 8120    e         x           s         n       f    n               a
# 8121    e         f           s         n       f    n               a
# 8123    e         x           s         n       f    n               a
#
#      gill_spacing gill_size gill_color  ... stalk_surface_below_ring  \
# ...

# %%
# count the data
len(mush[mush["cap_surface"]=="s"])
# Out:
# 2556

# %%
mush["cap_surface"].value_counts()
# Out:
# cap_surface
# y    3244
# s    2556
# f    2320
# g       4
# Name: count, dtype: int64

# %%
#to save this in data in local drive in csv file or excel

mush.to_csv("NewMush.csv",index=False)

# %%
pd.Series(count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pd.Series(count)
#
# NameError: name 'count' is not defined

# %%
# how to create a dataframe using value count

# %% [markdown]
# # bar plot
#
# # x aixs - categorical column
# # y axis - nu,erical column
#
# # where you are taking the data :
